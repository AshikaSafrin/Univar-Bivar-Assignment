# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("Placement.csv")
#1.1 Download the dataset

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.fillna(0,inplace=True)

# %%
dataset.isna().sum()
#1.2 Replace the Nan Values & i Change the Replace of nan values to 0.this dataset is they what marks get to now they how much get salary.so i change the nan to 0 value anything data values not change. that's why i choose the replace option
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset["status"].value_counts()
#1.3 67 members are not placed
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %%
#1.4 reason for not placed is they have low marks that's why not placed

# %%
dataset.corr(numeric_only=True)
#1.5 mba_p and salary relation is 0.13% it is postive correlation
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.min()
# Out:
# sl_no                      1
# gender                     F
# ssc_p                  40.89
# ssc_b                Central
# hsc_p                   37.0
# hsc_b                Central
# hsc_s                   Arts
# degree_p                50.0
# degree_t           Comm&Mgmt
# workex                    No
# etest_p                 50.0
# specialisation       Mkt&Fin
# mba_p                  51.21
# status            Not Placed
# salary                   0.0
# dtype: object

# %%
special=dataset.groupby(by="specialisation")["salary"].min()
min_specialisation=special.idxmin()
min_specialisation
#min_salary=special.min()
#1.6 Mkt & Fin specialisation is getting minimum salary
# Out:
# 'Mkt&Fin'

# %%
high_salary= dataset[dataset['salary'] > 500000]
salary= high_salary.shape[0]
salary
#1.7 3 peoples getting above 500000 salary
# Out:
# 3

# %%
import scipy.stats as stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
#1.8 this statement is false so null Hypothesis value is accept & Alternate Hypothesis value is Reject
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
degree=dataset[dataset["degree_t"]=='Sci&Tech']["salary"]
specialisation=dataset[dataset["specialisation"]=='Mkt&HR']["salary"]
ttest_ind(degree,specialisation)
#1.9 0.00<0.05 this statement is true so null value is rejected and Alternate value is accepted
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471179, df=152.0)

# %%
def stdNBgraph(dataset):
    mean=dataset.mean()
    std=dataset.std()
    values=[i for i in dataset]
    z_score=[((j-mean)/std) for j in values]
    sns.distplot(z_score,kde=True)
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["salary"])
# 1.10  already converted the N.D to S.N.D for salary column
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15752\1273660075.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='green')
    pyplot.axvline(startrange,color='red')
    pyplot.axvline(endrange,color='red')
    sample=dataset
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('mean=%.3f,standard deviation=%.3f'%(sample_mean,sample_std))
    dist=norm(sample_mean,sample_std)
    values=[value for value in range(startrange,endrange)]
    probabilities=[dist.pdf(value) for value in values]
    prob=sum(probabilities)
    print("the area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
#1.11 pdf salary column range is 0.00059
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15752\308306328.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='green')
# mean=198702.326,standard deviation=154780.927
# the area between range(700000,900000):0.0005973310593974901
# 0.0005973310593974901

# %%
from scipy.stats import ttest_rel
degree_t=dataset[dataset["degree_t"]=='Sci&Tech']["etest_p"]
degree_t1=dataset[dataset["degree_t"]=='Sci&Tech']["mba_p"]
ttest_rel(degree_t,degree_t1)
#1.12 this statement is false so null Hypothesis value is accept & Alternate Hypothesis value is Reject
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06, df=58)

# %%
dataset.corr(numeric_only=True)
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
correlation= dataset.corr(numeric_only=True)
salary= correlation['salary'].sort_values(ascending=False)
salary
#1.13 ssc_p is highly correlated with salary
# Out:
# salary      1.000000
# ssc_p       0.538090
# hsc_p       0.452569
# degree_p    0.408371
# etest_p     0.186988
# mba_p       0.139823
# sl_no       0.002543
# Name: salary, dtype: float64
